# %%
from google.colab import drive
drive.mount('/content/drive')

folder_path = '/content/drive/My Drive/Colab Notebooks/Ch4_HR_HRV_Generation/data-hrv-kaggle'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv(folder_path + '/test.csv')

# %%
for col in df.columns:
    print(col)
# Out:
# MEAN_RR
# MEDIAN_RR
# SDRR
# RMSSD
# SDSD
# SDRR_RMSSD
# HR
# pNN25
# pNN50
# SD1
# SD2
# KURT
# SKEW
# MEAN_REL_RR
# MEDIAN_REL_RR
# SDRR_REL_RR
# RMSSD_REL_RR
# SDSD_REL_RR
# SDRR_RMSSD_REL_RR
# KURT_REL_RR
# SKEW_REL_RR
# VLF
# VLF_PCT
# LF
# LF_PCT
# LF_NU
# HF
# HF_PCT
# HF_NU
# TP
# LF_HF
# HF_LF
# sampen
# higuci
# datasetId
# condition
