# %%
# !pip install -q moverscore
# !pip install -q pyemd
# !pip install -q pytorch_pretrained_bert
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for moverscore (setup.py) ... done
#   Building wheel for typing (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.6/662.6 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.6 MB/s eta 0:00:00

# %%
from moverscore import get_idf_dict, word_mover_score

def compute_moverscore(original, paraphrase):
    # Calculate IDF values based on both the reference and system sentences
    idf_dict_original = get_idf_dict([original])  # IDF for references
    idf_dict_paraphrase = get_idf_dict([paraphrase])   # IDF for system outputs

    # Compute MoverScore
    scores = word_mover_score([original], [paraphrase], idf_dict_original, idf_dict_paraphrase, stop_words=[], n_gram=1, remove_subwords=True)

    # Return the first (and only) score since we have one-to-one sentence comparison
    return scores[0]
# Out:
# Downloading https://github.com/AIPHES/emnlp19-moverscore/releases/download/0.6/MNLI_BERT.zip to /root/.moverscore/MNLI_BERT.zip
# [--------------------------------------------------]

# %%
original = "Our team has bearable performance base."
positive = "Our team is well-positioned for a triumphant victory."
negative = "Our team's chances of winning are quite doubtful."

# %%
# %%time

compute_moverscore(original, positive)
# Out:
# CPU times: user 673 ms, sys: 284 ms, total: 957 ms
# Wall time: 1.58 s
# 1.0

# %%
# %%time

compute_moverscore(original, negative)
# Out:
# CPU times: user 50.7 ms, sys: 114 ms, total: 165 ms
# Wall time: 278 ms
# 1.0
