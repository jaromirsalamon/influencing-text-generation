# %%
# !pip install tiktoken
# !pip install cohere
# !pip install openai

# %%
# !pip install --upgrade openai

# %%
from openai import OpenAI

client = OpenAI(
  api_key='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',  # this is also the default, it can be omitted
)

def paraphrase_with_signal(input_text, signal):
    if signal == 0:
        prompt = f"Please paraphrase the following text in a normal tone: {input_text}"
    elif signal == 1:
        prompt = f"Please paraphrase the following text in an excited or dramatic tone: {input_text}"
    else:
        return "Invalid signal. Please use 0 for normal or 1 for excited."

    try:
        response = completion = client.completions.create(
            model='gpt-3.5-turbo',  # Or another GPT model of your choice
            prompt=prompt,
            max_tokens=100
        )
        return response.choices[0].text.strip()
    except Exception as e:
        return f"An error occurred: {str(e)}"

# Example usage
input_text = "The quick brown fox jumps over the lazy dog."
signal = 0  # Change to 1 for excited or dramatic paraphrasing
paraphrased_text = paraphrase_with_signal(input_text, signal)
print(paraphrased_text)
# Out:
# An error occurred: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
