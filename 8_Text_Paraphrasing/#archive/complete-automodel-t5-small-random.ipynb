# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from torch.optim import AdamW
from sklearn.model_selection import train_test_split
import numpy as np
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class ParaphraseTripletDataset(Dataset):
    def __init__(self, triplets, tokenizer, max_length=512):
        self.tokenizer = tokenizer
        self.triplets = triplets
        self.max_length = max_length

    def __len__(self):
        return len(self.triplets)

    def __getitem__(self, idx):
        original, positive, negative = self.triplets[idx]
        return {
            'original': self.tokenizer(original, return_tensors='pt', max_length=self.max_length, truncation=True, padding='max_length'),
            'positive': self.tokenizer(positive, return_tensors='pt', max_length=self.max_length, truncation=True, padding='max_length'),
            'negative': self.tokenizer(negative, return_tensors='pt', max_length=self.max_length, truncation=True, padding='max_length'),
        }

# %%
model_name = 't5-small'  # You can choose a different model based on your needs
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def train_model_with_influence(model, data_loader, optimizer, epochs=3, device='cuda'):
    model.to(device)
    model.train()
    for epoch in range(epochs):
        for batch in data_loader:
            optimizer.zero_grad()
            rand_signal = random.choice(['positive', 'negative'])

            inputs = batch['original']['input_ids'].squeeze().to(device)  # Ensure correct shape
            attention_mask = batch['original']['attention_mask'].squeeze().to(device)  # Ensure correct shape
            if rand_signal == 'positive':
                targets = batch['positive']['input_ids'].squeeze().to(device)
            else:
                targets = batch['negative']['input_ids'].squeeze().to(device)

            labels = targets.clone()
            labels[labels == tokenizer.pad_token_id] = -100

            # Ensure labels are correctly shaped
            labels = labels.squeeze()  # Removing unnecessary dimensions if any

            try:
                outputs = model(input_ids=inputs, attention_mask=attention_mask, labels=labels)
                loss = outputs.loss
                loss.backward()
                optimizer.step()
                print(f"Epoch {epoch}, Loss: {loss.item()}, Chosen: {rand_signal}")
            except ValueError as e:
                print(f"Error during training: {str(e)}")
                # Inspect shapes if error occurs
                print(f"Input IDs shape: {inputs.shape}, Attention Mask shape: {attention_mask.shape}, Labels shape: {labels.shape}")

# %%
import pandas as pd

folder_input_path = '/content/drive/My Drive/Colab Notebooks/Ch3_Corpora/'
csv_file_path = 'sentiment-paraphrase-corpus-full-v1.csv'

# Read the CSV file
df = pd.read_csv(folder_input_path + csv_file_path)

# Convert the DataFrame to a list of triplets
triplets_data = list(df[['original', 'positive', 'negative']].itertuples(index=False, name=None))

# %%
# Splitting the dataset, preparing DataLoader, and optimizer
train_data, val_data = train_test_split(triplets_data, test_size=0.1)
train_dataset = ParaphraseTripletDataset(train_data, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True)
optimizer = AdamW(model.parameters(), lr=5e-5)

# Train the model with demonstration of influence
train_model_with_influence(model, train_loader, optimizer)
# Out:
# Epoch 0, Loss: 4.878786563873291, Chosen: negative
# Epoch 0, Loss: 2.4864819049835205, Chosen: positive
# Epoch 0, Loss: 3.241338014602661, Chosen: positive
# Epoch 0, Loss: 4.3642354011535645, Chosen: negative
# Epoch 0, Loss: 3.743809461593628, Chosen: positive
# Epoch 0, Loss: 4.1461076736450195, Chosen: positive
# Epoch 0, Loss: 3.297168254852295, Chosen: positive
# Epoch 0, Loss: 3.425661325454712, Chosen: positive
# Epoch 0, Loss: 3.1871325969696045, Chosen: negative
# Epoch 0, Loss: 2.826861619949341, Chosen: negative
# Epoch 0, Loss: 4.37708044052124, Chosen: negative
# Epoch 0, Loss: 2.4768426418304443, Chosen: positive
# Epoch 0, Loss: 3.691263198852539, Chosen: negative
# Epoch 0, Loss: 2.8047335147857666, Chosen: positive
# Epoch 0, Loss: 3.749321460723877, Chosen: positive
# Epoch 0, Loss: 3.5048131942749023, Chosen: negative
# Epoch 0, Loss: 3.1547048091888428, Chosen: positive
# Epoch 0, Loss: 2.4334840774536133, Chosen: positive
# Epoch 0, Loss: 2.5587024688720703, Chosen: positive
# Epoch 0, Loss: 3.1888949871063232, Chosen: negative
# Epoch 0, Loss: 5.158554553985596, Chosen: negative
# Epoch 0, Loss: 3.4358248710632324, Chosen: positive
# Epoch 0, Loss: 3.682252883911133, Chosen: negative
# Epoch 0, Loss: 3.2901434898376465, Chosen: positive
# Epoch 0, Loss: 2.8471972942352295, Chosen: positive
# Epoch 0, Loss: 3.1624739170074463, Chosen: positive
# Epoch 0, Loss: 2.75643253326416, Chosen: positive
# Epoch 0, Loss: 4.085404396057129, Chosen: negative
# Epoch 0, Loss: 3.046144723892212, Chosen: negative
# Epoch 0, Loss: 2.6634981632232666, Chosen: positive
# Epoch 0, Loss: 3.6646807193756104, Chosen: negative
# Epoch 0, Loss: 3.4309213161468506, Chosen: negative
# Epoch 0, Loss: 4.068661689758301, Chosen: negative
# Epoch 0, Loss: 2.713386297225952, Chosen: positive
# Epoch 0, Loss: 4.593487739562988, Chosen: negative
# Epoch 0, Loss: 3.065765857696533, Chosen: positive
# Epoch 0, Loss: 3.9605517387390137, Chosen: negative
# Epoch 0, Loss: 3.7955329418182373, Chosen: positive
# Epoch 0, Loss: 1.8111181259155273, Chosen: positive
# Epoch 0, Loss: 3.5072250366210938, Chosen: positive
# Epoch 0, Loss: 3.1652114391326904, Chosen: positive
# Epoch 0, Loss: 3.419804096221924, Chosen: negative
# Epoch 0, Loss: 3.0995357036590576, Chosen: negative
# Epoch 0, Loss: 4.1556267738342285, Chosen: negative
# Epoch 0, Loss: 3.5169105529785156, Chosen: negative
# Epoch 0, Loss: 3.755526065826416, Chosen: negative
# Epoch 0, Loss: 3.0327484607696533, Chosen: negative
# Epoch 0, Loss: 3.401201009750366, Chosen: positive
# Epoch 0, Loss: 2.9476306438446045, Chosen: negative
# Epoch 0, Loss: 3.4716532230377197, Chosen: negative
# Epoch 0, Loss: 4.370107650756836, Chosen: negative
# Epoch 0, Loss: 2.8659589290618896, Chosen: positive
# Epoch 0, Loss: 3.1967034339904785, Chosen: positive
# Epoch 0, Loss: 3.7305097579956055, Chosen: positive
# Epoch 0, Loss: 3.4859321117401123, Chosen: positive
# Epoch 0, Loss: 2.3031508922576904, Chosen: positive
# Epoch 0, Loss: 3.1945395469665527, Chosen: negative
# Epoch 0, Loss: 3.0093016624450684, Chosen: negative
# Epoch 0, Loss: 2.807727575302124, Chosen: positive
# Epoch 0, Loss: 2.11995267868042, Chosen: positive
# Epoch 0, Loss: 3.4457502365112305, Chosen: negative
# Epoch 0, Loss: 3.0235958099365234, Chosen: negative
# Epoch 0, Loss: 4.128521919250488, Chosen: negative
# Epoch 0, Loss: 3.6471667289733887, Chosen: negative
# Epoch 0, Loss: 2.6118180751800537, Chosen: positive
# Epoch 0, Loss: 2.630974769592285, Chosen: negative
# Epoch 0, Loss: 3.2563295364379883, Chosen: negative
# Epoch 0, Loss: 2.4013559818267822, Chosen: positive
# Epoch 0, Loss: 2.6029367446899414, Chosen: positive
# Epoch 0, Loss: 2.8239364624023438, Chosen: positive
# Epoch 0, Loss: 2.916377544403076, Chosen: positive
# Epoch 0, Loss: 3.3195667266845703, Chosen: negative
# Epoch 0, Loss: 3.4360158443450928, Chosen: negative
# Epoch 0, Loss: 3.1071829795837402, Chosen: negative
# Epoch 0, Loss: 2.929879903793335, Chosen: negative
# Epoch 0, Loss: 2.7657394409179688, Chosen: negative
# Epoch 0, Loss: 2.560576915740967, Chosen: positive
# Epoch 0, Loss: 2.8145861625671387, Chosen: positive
# Epoch 0, Loss: 2.1179959774017334, Chosen: positive
# Epoch 0, Loss: 2.754922389984131, Chosen: positive
# Epoch 0, Loss: 3.4319188594818115, Chosen: negative
# Epoch 0, Loss: 3.24906587600708, Chosen: negative
# Epoch 0, Loss: 2.464630365371704, Chosen: positive
# Epoch 0, Loss: 2.699721097946167, Chosen: negative
# Epoch 0, Loss: 2.13698148727417, Chosen: positive
# Epoch 0, Loss: 2.5969347953796387, Chosen: positive
# Epoch 0, Loss: 3.13181734085083, Chosen: positive
# Epoch 0, Loss: 2.9080734252929688, Chosen: negative
# Epoch 0, Loss: 2.866177558898926, Chosen: positive
# Epoch 0, Loss: 3.401017189025879, Chosen: negative
# Epoch 0, Loss: 2.4338459968566895, Chosen: positive
# Epoch 0, Loss: 1.8567250967025757, Chosen: positive
# Epoch 0, Loss: 1.8789438009262085, Chosen: positive
# Epoch 0, Loss: 4.413879871368408, Chosen: negative
# Epoch 0, Loss: 3.0070908069610596, Chosen: positive
# Epoch 1, Loss: 3.342883586883545, Chosen: negative
# Epoch 1, Loss: 2.8516006469726562, Chosen: positive
# Epoch 1, Loss: 3.4707839488983154, Chosen: negative
# Epoch 1, Loss: 1.816152811050415, Chosen: positive
# Epoch 1, Loss: 2.687507390975952, Chosen: positive
# Epoch 1, Loss: 3.509591579437256, Chosen: negative
# Epoch 1, Loss: 3.377473831176758, Chosen: negative
# Epoch 1, Loss: 2.286093235015869, Chosen: positive
# Epoch 1, Loss: 1.4968688488006592, Chosen: positive
# Epoch 1, Loss: 2.779958486557007, Chosen: negative
# Epoch 1, Loss: 2.7430171966552734, Chosen: negative
# Epoch 1, Loss: 4.214528560638428, Chosen: negative
# Epoch 1, Loss: 3.1216790676116943, Chosen: negative
# Epoch 1, Loss: 2.6040456295013428, Chosen: negative
# Epoch 1, Loss: 3.6024765968322754, Chosen: negative
# Epoch 1, Loss: 2.663320302963257, Chosen: negative
# Epoch 1, Loss: 2.779451608657837, Chosen: positive
# Epoch 1, Loss: 2.761897325515747, Chosen: negative
# Epoch 1, Loss: 2.2258448600769043, Chosen: positive
# Epoch 1, Loss: 2.7132108211517334, Chosen: positive
# Epoch 1, Loss: 3.0288870334625244, Chosen: negative
# Epoch 1, Loss: 2.045022964477539, Chosen: positive
# Epoch 1, Loss: 3.0582330226898193, Chosen: negative
# Epoch 1, Loss: 2.8306901454925537, Chosen: negative
# Epoch 1, Loss: 3.121641159057617, Chosen: positive
# Epoch 1, Loss: 2.8297836780548096, Chosen: negative
# Epoch 1, Loss: 2.9410033226013184, Chosen: positive
# Epoch 1, Loss: 2.6994123458862305, Chosen: negative
# Epoch 1, Loss: 2.7386648654937744, Chosen: positive
# Epoch 1, Loss: 2.486870288848877, Chosen: positive
# Epoch 1, Loss: 1.547285556793213, Chosen: positive
# Epoch 1, Loss: 2.3578615188598633, Chosen: positive
# Epoch 1, Loss: 3.032512903213501, Chosen: positive
# Epoch 1, Loss: 3.06815505027771, Chosen: positive
# Epoch 1, Loss: 3.3171815872192383, Chosen: negative
# Epoch 1, Loss: 2.648042917251587, Chosen: negative
# Epoch 1, Loss: 3.3991026878356934, Chosen: negative
# Epoch 1, Loss: 2.6982548236846924, Chosen: positive
# Epoch 1, Loss: 1.7263978719711304, Chosen: negative
# Epoch 1, Loss: 2.5775465965270996, Chosen: positive
# Epoch 1, Loss: 2.109795570373535, Chosen: positive
# Epoch 1, Loss: 2.33280086517334, Chosen: positive
# Epoch 1, Loss: 2.6387736797332764, Chosen: positive
# Epoch 1, Loss: 2.065167188644409, Chosen: positive
# Epoch 1, Loss: 2.270226001739502, Chosen: positive
# Epoch 1, Loss: 2.023798704147339, Chosen: positive
# Epoch 1, Loss: 3.1700222492218018, Chosen: positive
# Epoch 1, Loss: 2.99906849861145, Chosen: negative
# Epoch 1, Loss: 2.5422420501708984, Chosen: negative
# Epoch 1, Loss: 2.6583666801452637, Chosen: negative
# Epoch 1, Loss: 2.554147481918335, Chosen: positive
# Epoch 1, Loss: 2.0829334259033203, Chosen: positive
# Epoch 1, Loss: 3.149196147918701, Chosen: negative
# Epoch 1, Loss: 3.3438353538513184, Chosen: negative
# Epoch 1, Loss: 3.248809337615967, Chosen: negative
# Epoch 1, Loss: 3.4760804176330566, Chosen: negative
# Epoch 1, Loss: 2.39101505279541, Chosen: positive
# Epoch 1, Loss: 3.1029927730560303, Chosen: negative
# Epoch 1, Loss: 2.7757771015167236, Chosen: negative
# Epoch 1, Loss: 2.395684003829956, Chosen: negative
# Epoch 1, Loss: 2.262010097503662, Chosen: positive
# Epoch 1, Loss: 3.2747349739074707, Chosen: positive
# Epoch 1, Loss: 2.718078374862671, Chosen: positive
# Epoch 1, Loss: 1.838516116142273, Chosen: positive
# Epoch 1, Loss: 3.0175528526306152, Chosen: negative
# Epoch 1, Loss: 2.4715027809143066, Chosen: negative
# Epoch 1, Loss: 2.245802640914917, Chosen: positive
# Epoch 1, Loss: 2.8429160118103027, Chosen: negative
# Epoch 1, Loss: 2.2633252143859863, Chosen: negative
# Epoch 1, Loss: 2.422092914581299, Chosen: positive
# Epoch 1, Loss: 2.226426601409912, Chosen: positive
# Epoch 1, Loss: 2.2032365798950195, Chosen: negative
# Epoch 1, Loss: 3.5377557277679443, Chosen: negative
# Epoch 1, Loss: 2.952755928039551, Chosen: negative
# Epoch 1, Loss: 2.3604440689086914, Chosen: positive
# Epoch 1, Loss: 3.732743263244629, Chosen: negative
# Epoch 1, Loss: 2.6376161575317383, Chosen: negative
# Epoch 1, Loss: 2.785144567489624, Chosen: negative
# Epoch 1, Loss: 1.4442919492721558, Chosen: positive
# Epoch 1, Loss: 2.3713128566741943, Chosen: positive
# Epoch 1, Loss: 2.7026467323303223, Chosen: positive
# Epoch 1, Loss: 2.568587303161621, Chosen: negative
# Epoch 1, Loss: 2.7095389366149902, Chosen: negative
# Epoch 1, Loss: 2.5463151931762695, Chosen: negative
# Epoch 1, Loss: 2.1905405521392822, Chosen: positive
# Epoch 1, Loss: 2.904263496398926, Chosen: negative
# Epoch 1, Loss: 2.744943380355835, Chosen: negative
# Epoch 1, Loss: 2.822118043899536, Chosen: negative
# Epoch 1, Loss: 3.0979111194610596, Chosen: negative
# Epoch 1, Loss: 2.6007800102233887, Chosen: positive
# Epoch 1, Loss: 2.1166493892669678, Chosen: positive
# Epoch 1, Loss: 2.268618583679199, Chosen: positive
# Epoch 1, Loss: 2.4398193359375, Chosen: positive
# Epoch 1, Loss: 3.282223701477051, Chosen: negative
# Epoch 1, Loss: 2.9091544151306152, Chosen: negative
# Epoch 2, Loss: 1.290597677230835, Chosen: positive
# Epoch 2, Loss: 2.643613576889038, Chosen: negative
# Epoch 2, Loss: 2.223803758621216, Chosen: positive
# Epoch 2, Loss: 2.6654789447784424, Chosen: positive
# Epoch 2, Loss: 3.0096771717071533, Chosen: negative
# Epoch 2, Loss: 2.526303768157959, Chosen: negative
# Epoch 2, Loss: 2.1435232162475586, Chosen: positive
# Epoch 2, Loss: 1.7911370992660522, Chosen: positive
# Epoch 2, Loss: 2.765946865081787, Chosen: positive
# Epoch 2, Loss: 3.052042245864868, Chosen: negative
# Epoch 2, Loss: 2.4748005867004395, Chosen: positive
# Epoch 2, Loss: 1.846490740776062, Chosen: positive
# Epoch 2, Loss: 1.797188639640808, Chosen: positive
# Epoch 2, Loss: 2.583622694015503, Chosen: positive
# Epoch 2, Loss: 2.7239468097686768, Chosen: positive
# Epoch 2, Loss: 1.9893759489059448, Chosen: positive
# Epoch 2, Loss: 2.60152268409729, Chosen: negative
# Epoch 2, Loss: 3.163450002670288, Chosen: negative
# Epoch 2, Loss: 3.7985994815826416, Chosen: negative
# Epoch 2, Loss: 2.485135555267334, Chosen: negative
# Epoch 2, Loss: 2.236236810684204, Chosen: positive
# Epoch 2, Loss: 2.5642292499542236, Chosen: positive
# Epoch 2, Loss: 2.913315773010254, Chosen: negative
# Epoch 2, Loss: 2.6318507194519043, Chosen: positive
# Epoch 2, Loss: 2.9005255699157715, Chosen: positive
# Epoch 2, Loss: 2.424278974533081, Chosen: positive
# Epoch 2, Loss: 2.2022228240966797, Chosen: positive
# Epoch 2, Loss: 2.357231378555298, Chosen: negative
# Epoch 2, Loss: 2.5619425773620605, Chosen: negative
# Epoch 2, Loss: 2.6555304527282715, Chosen: negative
# Epoch 2, Loss: 1.6422200202941895, Chosen: positive
# Epoch 2, Loss: 2.4707064628601074, Chosen: positive
# Epoch 2, Loss: 2.07163143157959, Chosen: positive
# Epoch 2, Loss: 2.7797203063964844, Chosen: negative
# Epoch 2, Loss: 2.3130064010620117, Chosen: negative
# Epoch 2, Loss: 2.32560396194458, Chosen: positive
# Epoch 2, Loss: 3.7302796840667725, Chosen: negative
# Epoch 2, Loss: 2.1089186668395996, Chosen: negative
# Epoch 2, Loss: 1.8164552450180054, Chosen: positive
# Epoch 2, Loss: 1.4441832304000854, Chosen: positive
# Epoch 2, Loss: 2.628570318222046, Chosen: negative
# Epoch 2, Loss: 2.251873254776001, Chosen: positive
# Epoch 2, Loss: 1.8635088205337524, Chosen: negative
# Epoch 2, Loss: 1.975108027458191, Chosen: positive
# Epoch 2, Loss: 1.89960515499115, Chosen: positive
# Epoch 2, Loss: 1.9712473154067993, Chosen: negative
# Epoch 2, Loss: 2.76737642288208, Chosen: negative
# Epoch 2, Loss: 2.7350635528564453, Chosen: negative
# Epoch 2, Loss: 2.757732629776001, Chosen: positive
# Epoch 2, Loss: 2.0406556129455566, Chosen: negative
# Epoch 2, Loss: 2.748548984527588, Chosen: negative
# Epoch 2, Loss: 2.9500253200531006, Chosen: negative
# Epoch 2, Loss: 2.4330079555511475, Chosen: positive
# Epoch 2, Loss: 2.0964529514312744, Chosen: positive
# Epoch 2, Loss: 2.461620569229126, Chosen: negative
# Epoch 2, Loss: 2.5639002323150635, Chosen: positive
# Epoch 2, Loss: 2.582052230834961, Chosen: negative
# Epoch 2, Loss: 2.3592731952667236, Chosen: positive
# Epoch 2, Loss: 2.636453628540039, Chosen: negative
# Epoch 2, Loss: 3.2740848064422607, Chosen: negative
# Epoch 2, Loss: 2.5203030109405518, Chosen: negative
# Epoch 2, Loss: 2.2743585109710693, Chosen: negative
# Epoch 2, Loss: 2.3707611560821533, Chosen: positive
# Epoch 2, Loss: 2.2961299419403076, Chosen: negative
# Epoch 2, Loss: 1.994077205657959, Chosen: negative
# Epoch 2, Loss: 2.705657958984375, Chosen: positive
# Epoch 2, Loss: 1.9624316692352295, Chosen: positive
# Epoch 2, Loss: 2.2505815029144287, Chosen: positive
# Epoch 2, Loss: 2.573718786239624, Chosen: negative
# Epoch 2, Loss: 2.4976119995117188, Chosen: positive
# Epoch 2, Loss: 2.4142801761627197, Chosen: positive
# Epoch 2, Loss: 1.745026707649231, Chosen: positive
# Epoch 2, Loss: 2.624901056289673, Chosen: positive
# Epoch 2, Loss: 1.517145037651062, Chosen: positive
# Epoch 2, Loss: 2.6678853034973145, Chosen: negative
# Epoch 2, Loss: 2.54766583442688, Chosen: negative
# Epoch 2, Loss: 2.5232555866241455, Chosen: positive
# Epoch 2, Loss: 2.434962511062622, Chosen: negative
# Epoch 2, Loss: 2.2066314220428467, Chosen: negative
# Epoch 2, Loss: 2.877736806869507, Chosen: positive
# Epoch 2, Loss: 2.6538760662078857, Chosen: positive
# Epoch 2, Loss: 2.8305935859680176, Chosen: negative
# Epoch 2, Loss: 1.9067541360855103, Chosen: positive
# Epoch 2, Loss: 2.721275568008423, Chosen: negative
# Epoch 2, Loss: 2.446495294570923, Chosen: positive
# Epoch 2, Loss: 1.7107324600219727, Chosen: positive
# Epoch 2, Loss: 2.504379987716675, Chosen: negative
# Epoch 2, Loss: 2.2834696769714355, Chosen: negative
# Epoch 2, Loss: 3.15293288230896, Chosen: positive
# Epoch 2, Loss: 2.5268852710723877, Chosen: negative
# Epoch 2, Loss: 2.910278558731079, Chosen: negative
# Epoch 2, Loss: 3.201798677444458, Chosen: positive
# Epoch 2, Loss: 2.5206234455108643, Chosen: positive
# Epoch 2, Loss: 2.2050437927246094, Chosen: positive
# Epoch 2, Loss: 3.3430399894714355, Chosen: negative

# %%
def evaluate_model(model, data_loader, device='cuda'):
    model.eval()  # Set the model to evaluation mode
    total_loss = 0
    with torch.no_grad():  # No need to track gradients during evaluation
        for batch in data_loader:
            inputs = batch['original']['input_ids'].squeeze().to(device)
            attention_mask = batch['original']['attention_mask'].squeeze().to(device)
            # Choose the type of paraphrase for evaluation; let's say positive for simplicity
            targets = batch['positive']['input_ids'].squeeze().to(device)
            labels = targets.clone()
            labels[labels == tokenizer.pad_token_id] = -100
            outputs = model(input_ids=inputs, attention_mask=attention_mask, labels=labels)
            total_loss += outputs.loss.item()
    avg_loss = total_loss / len(data_loader)
    print(f"Average loss: {avg_loss}")
    # Implement additional metrics as needed

# %%
val_dataset = ParaphraseTripletDataset(val_data, tokenizer)
val_loader = DataLoader(val_dataset, batch_size=2, shuffle=True)

evaluate_model(model, val_loader, device='cuda')
# Out:
# Average loss: 2.009604421528903

# %%
model_save_path = 'path_to_save_your_model'
model.save_pretrained(model_save_path)
tokenizer.save_pretrained(model_save_path)

# %%
def generate_paraphrase(input_sentence, model, tokenizer, tone='positive', device='cuda', max_length=512):
    model.eval()
    # Incorporate the tone into the input prompt in a way the model understands
    prompt = f"{input_sentence} [Tone: {tone}]"  # This is highly model-dependent

    input_ids = tokenizer.encode(prompt, return_tensors="pt", add_special_tokens=True).to(device)
    attention_mask = (input_ids != tokenizer.pad_token_id).to(device)

    # Generate paraphrase
    output_sequences = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=max_length)

    # Decode generated sequence to text
    paraphrase = tokenizer.decode(output_sequences[0], skip_special_tokens=True)
    return paraphrase

# %%
input_sentence = "The meal was served promptly." #"The story was predictable."
positive_paraphrase = generate_paraphrase(input_sentence, model, tokenizer, tone='positive')
negative_paraphrase = generate_paraphrase(input_sentence, model, tokenizer, tone='negative')

print("Original:", input_sentence)
print("Positive Paraphrase:", positive_paraphrase)
print("Negative Paraphrase:", negative_paraphrase)
# Out:
# Original: The meal was served promptly.
# Positive Paraphrase: The meal was excellent and was very good.
# Negative Paraphrase: The meal was a bit disappointing and a bit disappointing.
