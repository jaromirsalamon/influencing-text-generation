# %%
# !pip uninstall pyarrow -y
# !pip install -q pyarrow==12.0.0
# Out:
# Found existing installation: pyarrow 10.0.1
# Uninstalling pyarrow-10.0.1:
#   Successfully uninstalled pyarrow-10.0.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 23.2 MB/s eta 0:00:00

# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.0 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds = 'manual' # 'mrpc','manual'
# sentiment = 'positive' # 'positive', 'negative'

folder_input_path = '/content/drive/My Drive/Colab Notebooks/5_Corpora/corpora/'
folder_pretrained_path = '/content/drive/My Drive/Colab Notebooks/8_Text_Paraphrasing/pretrained'
csv_file_path = f'{ds}-triplet-corpus.csv'

# %%
from datasets import Dataset
import pandas as pd

df = pd.read_csv(folder_input_path + csv_file_path)
dataset = df[['original', 'positive']].rename(columns={'original': 'input_text', 'positive': 'target_text'}) # Adjust based on sentiment
dataset = Dataset.from_pandas(dataset)

dataset
# Out:
# Dataset({
#     features: ['input_text', 'target_text'],
#     num_rows: 212
# })

# %%
dataset['input_text'][:5]
# Out:
# ['I usually wake up early in the morning.',
#  'I regularly take a walk in the evening.',
#  'The weather is unpredictable today.',
#  'The restaurant offers food.',
#  'This movie features a standard plot.']

# %%
from datasets import load_dataset

raw_dataset = load_dataset("csv", data_files=(folder_input_path + csv_file_path))
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['original', 'positive', 'negative', 'positive_cos_sim', 'negative_cos_sim', 'original_label', 'positive_label', 'negative_label', 'original_sentiment_label', 'original_sentiment_score', 'positive_sentiment_label', 'positive_sentiment_score', 'negative_sentiment_label', 'negative_sentiment_score', 'positive_bleu', 'negative_bleu', 'positive_rouge_n', 'positive_rouge_s', 'positive_rouge_l', 'negative_rouge_n', 'negative_rouge_s', 'negative_rouge_l', 'positive_meteor', 'negative_meteor', 'positive_ter', 'negative_ter', 'positive_chrf', 'negative_chrf', 'positive_chrfpp', 'negative_chrfpp', 'positive_mover', 'negative_mover', 'positive_bert', 'negative_bert', 'positive_bleurt', 'negative_bleurt', 'positive_cosine_similarity', 'negative_cosine_similarity'],
#         num_rows: 212
#     })
# })
